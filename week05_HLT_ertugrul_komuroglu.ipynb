# %% [markdown]
# Task 01

# %%
import pandas as pd 
data = pd.read_csv("destinations.csv")
data.shape
data
# Out:
#                 Destinations  Feedback_score  Average_star_rating  \
# 0                    Senegal               4                    1
# 1                       Guam               5                    5
# 2     British Virgin Islands               6                    4
# 3             Western Sahara               8                    2
# 4   Central African Republic               6                    1
# 5                     Brunei               4                    3
# 6                   Cambodia               8                    4
# 7                      Libya               7                    5
# 8              United States               9                    1
# 9                 Cape Verde               6                    2
# 10                    Zambia               3                    3
# 11                 Indonesia               5                    4
# 12                San Marino               4                    2
# ...

# %% [markdown]
# Task 02

# %%
import pandas as pd 
data = pd.read_csv("destinations.csv")
data.iloc[3:9]
# Out:
#                Destinations  Feedback_score  Average_star_rating  \
# 3            Western Sahara               8                    2
# 4  Central African Republic               6                    1
# 5                    Brunei               4                    3
# 6                  Cambodia               8                    4
# 7                     Libya               7                    5
# 8             United States               9                    1
#
#    Number_of_holtels Most_visited_cities
# 3                 45            El Marsa
# 4                 12           Berberati
# 5                 45               Seria
# 6                 45          Phnom Penh
# 7                 12             Tripoli
# 8                 36              Boston

# %% [markdown]
# Task 04

# %%
import pandas as pd 
data = pd.read_csv("destinations.csv")
score_filter = data["Feedback_score"] < 5
low_score = data[score_filter]
low_score.head(15)
# Out:
#    Destinations  Feedback_score  Average_star_rating  Number_of_holtels  \
# 0       Senegal               4                    1                 12
# 5        Brunei               4                    3                 45
# 10       Zambia               3                    3                 52
# 12   San Marino               4                    2                 25
# 13     Ethiopia               2                    3                 12
# 14      Lebanon               4                    2                 45
#
#    Most_visited_cities
# 0                Dakar
# 5                Seria
# 10              Lusaka
# 12         Serravalle
# 13              Gonkar
# 14              Beirut

# %% [markdown]
# Task 05

# %%
import pandas as pd 
data = pd.read_csv("destinations.csv")
hi_filter = data["Feedback_score"] >5
hi_score = data[hi_filter]
hi_score.head()
# Out:
#                Destinations  Feedback_score  Average_star_rating  \
# 2    British Virgin Islands               6                    4
# 3            Western Sahara               8                    2
# 4  Central African Republic               6                    1
# 6                  Cambodia               8                    4
# 7                     Libya               7                    5
#
#    Number_of_holtels Most_visited_cities
# 2                 23             Tortola
# 3                 45            El Marsa
# 4                 12           Berberati
# 6                 45          Phnom Penh
# 7                 12             Tripoli

# %% [markdown]
# Task 06

# %%
import pandas as pd
data = pd.read_csv("destinations.csv")
hotel_filter = data["Number_of_holtels"] > 40
hotels = data[hotel_filter]
hotels.shape
# Out:
# (8, 5)

# %% [markdown]
# Task 07

# %%
import pandas as pd 
data = pd.read_csv("destinations.csv")
hi_filter = data["Feedback_score"] > 8
hi_score = data[hi_filter]
hi_score
# Out:
#     Destinations  Feedback_score  Average_star_rating  Number_of_holtels  \
# 8  United States               9                    1                 36
#
#   Most_visited_cities
# 8              Boston

# %% [markdown]
# Task 08

# %%
import pandas as pd 
data = pd.read_csv("destinations.csv")
lo_filter = data["Feedback_score"] < 3
lo_score = data[lo_filter]
lo_score
# Out:
#    Destinations  Feedback_score  Average_star_rating  Number_of_holtels  \
# 13     Ethiopia               2                    3                 12
#
#    Most_visited_cities
# 13              Gonkar
